# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Louis Jack Anthony Suharso]
# - **Email:** [suharsolouis@gmail.com]
# - **ID Dicoding:** [louis_suharso]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Which hours have the highest average bike rental demand on working days versus weekends/holidays during 2011–2012, and what operational periods should be prioritized based on these differences?
# - **Pertanyaan 2:** How do weather conditions and seasons affect average bike rental demand during 2011–2012, and how should these patterns be considered in operational planning?
# - ...

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import os
from google.colab import files

import warnings
warnings.filterwarnings('ignore')

# Display all columns when viewing DataFrames
pd.set_option('display.max_columns', None)

# Set visualization style
sns.set_theme(style='whitegrid')

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load the Dataset
#
# The dataset used in this project is the Bike Sharing Dataset.
#
# The analysis uses the hourly bike-sharing data stored in `hour.csv`. The dataset contains hourly rental information from 2011 to 2012, including rental counts, user types, weather conditions, seasons, and time-related variables.
#
# The hourly dataset is used because it allows us to analyze rental demand at different hours of the day.

# %%
#Load Dataset

df = pd.read_csv('hour.csv')

print("Dataset loaded successfully.")
print(f"Number of rows    : {df.shape[0]:,}")
print(f"Number of columns : {df.shape[1]}")
# Out:
# Dataset loaded successfully.
# Number of rows    : 17,379
# Number of columns : 17

# %%
#Display the first 5 rows
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
#Display Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
#Display Descriptive Statistics
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - The dataset contains 17,379 hourly observations and 17 variables.
# - The data covers bike-sharing activity from 2011 to 2012.
# - The dataset contains information about time, weather, environmental conditions, casual users, registered users, and total rental counts.
# - The `cnt` variable represents the total number of bike rentals and will be used as the primary measure of bike-sharing demand.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying Data Quality Problems
#
# The dataset will be assessed to identify potential data quality problems before conducting the analysis.
#
# The assessment focuses on:
#
# 1. Missing values
# 2. Duplicate records
# 3. Invalid values
# 4. Inconsistent values
# 5. Potential outliers

# %% [markdown]
# #### Identifying Missing Values
#
# Missing values are checked to determine whether any observations contain incomplete information.

# %%
# Check for missing values

missing_values = df.isna().sum()

missing_percentage = (
    df.isna().mean() * 100
).round(2)

missing_table = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

missing_table
# Out:
#             Missing Values  Percentage (%)
# instant                  0             0.0
# dteday                   0             0.0
# season                   0             0.0
# yr                       0             0.0
# mnth                     0             0.0
# hr                       0             0.0
# holiday                  0             0.0
# weekday                  0             0.0
# workingday               0             0.0
# weathersit               0             0.0
# temp                     0             0.0
# atemp                    0             0.0
# hum                      0             0.0
# windspeed                0             0.0
# casual                   0             0.0
# registered               0             0.0
# cnt                      0             0.0

# %% [markdown]
# #### Identifying Duplicate Records
#
# Duplicate records are checked to ensure that the same observation has not been recorded more than once.

# %%
# Check for duplicate rows

duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# #### Identifying Invalid Values
#
# Several variables are checked against their expected ranges.
#
# For example, `hr` should range from 0 to 23 because it represents the hour of the day. Other normalized variables such as temperature, humidity, and windspeed are also examined.

# %%
# Check the range of selected numerical variables

print("Hour:")
print(f"Minimum: {df['hr'].min()}")
print(f"Maximum: {df['hr'].max()}")

print("\nTemperature:")
print(f"Minimum: {df['temp'].min()}")
print(f"Maximum: {df['temp'].max()}")

print("\nHumidity:")
print(f"Minimum: {df['hum'].min()}")
print(f"Maximum: {df['hum'].max()}")

print("\nWindspeed:")
print(f"Minimum: {df['windspeed'].min()}")
print(f"Maximum: {df['windspeed'].max()}")
# Out:
# Hour:
# Minimum: 0
# Maximum: 23
#
# Temperature:
# Minimum: 0.02
# Maximum: 1.0
#
# Humidity:
# Minimum: 0.0
# Maximum: 1.0
#
# Windspeed:
# Minimum: 0.0
# Maximum: 0.8507

# %%
# Check for invalid hour values

invalid_hr = df[
    (df['hr'] < 0) |
    (df['hr'] > 23)
]

print(
    f"Number of invalid hour values: {len(invalid_hr)}"
)
# Out:
# Number of invalid hour values: 0

# %% [markdown]
# #### Identifying Invalid Rental Counts
#
# Rental counts should not contain negative values because the number of rentals cannot be negative.

# %%
# Check for negative rental values

print(
    "Negative casual values:",
    (df['casual'] < 0).sum()
)

print(
    "Negative registered values:",
    (df['registered'] < 0).sum()
)

print(
    "Negative total rental values:",
    (df['cnt'] < 0).sum()
)
# Out:
# Negative casual values: 0
# Negative registered values: 0
# Negative total rental values: 0

# %% [markdown]
# #### Identifying Inconsistent Rental Counts
#
# The dataset provides rental counts for casual and registered users as well as the total rental count.
#
# The following relationship should hold:
#
# `casual + registered = cnt`
#
# This relationship is checked to identify inconsistent observations.

# %%
# Calculate the total rental count from casual and registered users

df['calculated_cnt'] = (
    df['casual'] + df['registered']
)

# Check whether the calculated total matches cnt

inconsistent_count = (
    df['calculated_cnt'] != df['cnt']
).sum()

print(
    "Number of inconsistent rental records:",
    inconsistent_count
)
# Out:
# Number of inconsistent rental records: 0

# %% [markdown]
# #### Identifying Potential Outliers
#
# Potential outliers in the total rental count (`cnt`) are identified using the Interquartile Range (IQR) method.
#
# The IQR method identifies observations that fall substantially above or below the central range of the data.
#
# However, a statistical outlier is not necessarily an error. In this dataset, unusually high rental counts may represent genuine periods of high demand.

# %%
# Calculate the IQR for total rental count

Q1 = df['cnt'].quantile(0.25)
Q3 = df['cnt'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[
    (df['cnt'] < lower_bound) |
    (df['cnt'] > upper_bound)
]

print(f"Q1: {Q1:.2f}")
print(f"Q3: {Q3:.2f}")
print(f"IQR: {IQR:.2f}")
print(f"Lower Bound: {lower_bound:.2f}")
print(f"Upper Bound: {upper_bound:.2f}")

print(
    f"\nNumber of potential outliers: {len(outliers):,}"
)
# Out:
# Q1: 40.00
# Q3: 281.00
# IQR: 241.00
# Lower Bound: -321.50
# Upper Bound: 642.50
#
# Number of potential outliers: 505

# %%
# Visualize the distribution of total rental counts

plt.figure(figsize=(10, 5))

sns.boxplot(x=df['cnt'])

plt.title('Distribution of Total Bike Rentals')
plt.xlabel('Number of Rentals')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Steps to Take:**
#
# - No missing-value treatment is required because no missing values were identified.
# - No duplicate removal is required because no duplicate records were identified.
# - No invalid-hour correction is required because all hour values are within the expected range of 0–23.
# - No correction is required for rental-count consistency because `casual + registered` matches `cnt` for all observations.
# - The 505 potential outliers in `cnt` will be retained because they may represent genuine periods of high bike-sharing demand rather than data-entry errors.
# - The temporary `calculated_cnt` column will be removed after the assessment.
# - The `instant` column will also be removed because it functions as an index and is not required for the business analysis.

# %% [markdown]
# **Insight:**
#
# The assessment shows that the dataset has good overall data quality. There are no missing values, duplicate records, invalid hour values, or inconsistencies between the user-level rental counts and total rental counts.
#
# The only notable issue is the presence of 505 potential outliers in `cnt`. These observations are retained because unusually high rental counts can represent genuine high-demand periods that are relevant to the business analysis.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Cleaning and Preparing the Dataset
#
# Based on the assessment results, the dataset does not require extensive correction because no missing values, duplicate records, or inconsistent values were identified.
#
# The following preparation steps will be performed:
#
# - Convert `dteday` into datetime format.
# - Remove the temporary `calculated_cnt` column.
# - Remove the `instant` index column.
# - Create descriptive labels for categorical variables.

# %%
# Create a copy of the original dataset

df_clean = df.copy()

print("Clean dataset created successfully.")
# Out:
# Clean dataset created successfully.

# %%
# Remove duplicate records

df_clean = df_clean.drop_duplicates()

print(
    f"Number of rows after removing duplicates: "
    f"{len(df_clean):,}"
)
# Out:
# Number of rows after removing duplicates: 17,379

# %%
# Convert the date column to datetime format

df_clean['dteday'] = pd.to_datetime(
    df_clean['dteday']
)

print(
    "Data type of dteday:",
    df_clean['dteday'].dtype
)
# Out:
# Data type of dteday: datetime64[ns]

# %%
# Remove columns that are not needed for analysis

df_clean = df_clean.drop(
    columns=[
        'instant',
        'calculated_cnt'
    ],
    errors='ignore'
)

print("Unnecessary columns removed.")
# Out:
# Unnecessary columns removed.

# %%
# Convert season codes into descriptive labels

season_mapping = {
    1: 'Spring',
    2: 'Summer',
    3: 'Fall',
    4: 'Winter'
}

df_clean['season_name'] = (
    df_clean['season'].map(season_mapping)
)

# %%
# Convert weather codes into descriptive labels

weather_mapping = {
    1: 'Clear',
    2: 'Mist / Cloudy',
    3: 'Light Rain / Snow',
    4: 'Heavy Rain / Snow'
}

df_clean['weather_name'] = (
    df_clean['weathersit'].map(weather_mapping)
)

# %%
# Convert the workingday variable into descriptive categories

workingday_mapping = {
    0: 'Weekend / Holiday',
    1: 'Working Day'
}

df_clean['day_type'] = (
    df_clean['workingday'].map(workingday_mapping)
)

# %%
# Convert month codes into descriptive month names

month_mapping = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}

df_clean['month_name'] = (
    df_clean['mnth'].map(month_mapping)
)

# %%
# Convert encoded year values into actual years

year_mapping = {
    0: 2011,
    1: 2012
}

df_clean['year'] = (
    df_clean['yr'].map(year_mapping)
)

# %%
# Convert encoded year values into actual years

year_mapping = {
    0: 2011,
    1: 2012
}

df_clean['year'] = (
    df_clean['yr'].map(year_mapping)
)

# %%
# Display the cleaned dataset

df_clean.head()
# Out:
#       dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0 2011-01-01       1   0     1   0        0        6           0           1
# 1 2011-01-01       1   0     1   1        0        6           0           1
# 2 2011-01-01       1   0     1   2        0        6           0           1
# 3 2011-01-01       1   0     1   3        0        6           0           1
# 4 2011-01-01       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt season_name  \
# 0  0.24  0.2879  0.81        0.0       3          13   16      Spring
# 1  0.22  0.2727  0.80        0.0       8          32   40      Spring
# 2  0.22  0.2727  0.80        0.0       5          27   32      Spring
# 3  0.24  0.2879  0.75        0.0       3          10   13      Spring
# 4  0.24  0.2879  0.75        0.0       0           1    1      Spring
#
#   weather_name           day_type month_name  year
# ...

# %% [markdown]
# **Insight:**
#
# The cleaning process confirms that the dataset is suitable for further analysis. No records were removed because of missing or inconsistent values.
#
# The main preparation involved converting the date variable into datetime format, removing non-analytical columns, and creating descriptive categorical labels to make the subsequent analysis easier to interpret.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Exploring Bike Rental Demand
#
# Exploratory Data Analysis is conducted to answer the two business questions.
#
# The analysis focuses on:
#
# 1. Hourly rental demand on working days and weekends/holidays.
# 2. The relationship between rental demand, weather conditions, and seasons.

# %% [markdown]
# #### Business Question 1
#
# Which hours have the highest average bike rental demand on working days versus weekends/holidays during 2011–2012, and what operational periods should be prioritized based on these differences?

# %%
# Calculate average rental demand by hour and day type

hourly_demand = (
    df_clean
    .groupby(['day_type', 'hr'])['cnt']
    .mean()
    .reset_index()
)

hourly_demand.head()
# Out:
#             day_type  hr        cnt
# 0  Weekend / Holiday   0  90.800000
# 1  Weekend / Holiday   1  69.508696
# 2  Weekend / Holiday   2  53.171053
# 3  Weekend / Holiday   3  25.775330
# 4  Weekend / Holiday   4   8.264317

# %%
# Identify the peak rental hour for each day type

peak_by_day_type = (
    hourly_demand.loc[
        hourly_demand.groupby('day_type')['cnt'].idxmax()
    ]
    .sort_values('day_type')
)

peak_by_day_type
# Out:
#              day_type  hr         cnt
# 13  Weekend / Holiday  13  372.731602
# 41        Working Day  17  525.290581

# %%
# Identify the five highest-demand hours for each day type

top_hours = (
    hourly_demand
    .sort_values(
        ['day_type', 'cnt'],
        ascending=[True, False]
    )
    .groupby('day_type')
    .head(5)
)

top_hours
# Out:
#              day_type  hr         cnt
# 13  Weekend / Holiday  13  372.731602
# 12  Weekend / Holiday  12  366.259740
# 14  Weekend / Holiday  14  364.645022
# 15  Weekend / Holiday  15  358.813853
# 16  Weekend / Holiday  16  352.727273
# 41        Working Day  17  525.290581
# 42        Working Day  18  492.226908
# 32        Working Day   8  477.006048
# 43        Working Day  19  348.401606
# 40        Working Day  16  293.122244

# %% [markdown]
# #### Business Question 2
#
# How do weather conditions and seasons affect average bike rental demand during 2011–2012, and how should these patterns be considered in operational planning?

# %%
# Calculate average rental demand by weather condition

weather_summary = (
    df_clean
    .groupby('weather_name')
    .agg(
        average_rental=('cnt', 'mean'),
        total_rental=('cnt', 'sum'),
        observations=('cnt', 'count')
    )
    .sort_values(
        'average_rental',
        ascending=False
    )
)

weather_summary
# Out:
#                    average_rental  total_rental  observations
# weather_name
# Clear                  204.869272       2338173         11413
# Mist / Cloudy          175.165493        795952          4544
# Light Rain / Snow      111.579281        158331          1419
# Heavy Rain / Snow       74.333333           223             3

# %%
# Calculate average rental demand by season

season_summary = (
    df_clean
    .groupby('season_name')
    .agg(
        average_rental=('cnt', 'mean'),
        total_rental=('cnt', 'sum'),
        observations=('cnt', 'count')
    )
    .sort_values(
        'average_rental',
        ascending=False
    )
)

season_summary
# Out:
#              average_rental  total_rental  observations
# season_name
# Fall             236.016237       1061129          4496
# Summer           208.344069        918589          4409
# Winter           198.868856        841613          4232
# Spring           111.114569        471348          4242

# %%
# Analyze the combined effect of season and weather

weather_season = pd.pivot_table(
    df_clean,
    values='cnt',
    index='season_name',
    columns='weather_name',
    aggfunc='mean'
)

weather_season
# Out:
# weather_name       Clear  Heavy Rain / Snow  Light Rain / Snow  Mist / Cloudy
# season_name
# Fall          244.494207                NaN         171.955390     224.848997
# Spring        122.055535          74.333333          58.650407     103.074689
# Summer        232.410983                NaN         115.179803     181.261364
# Winter        209.463779                NaN         116.453333     201.483974

# %% [markdown]
# **Insight:**
#
# The exploratory analysis provides two important perspectives on bike-sharing demand.
#
# First, rental demand varies substantially by hour and day type. Working days and weekends/holidays show different demand patterns, indicating that operational planning should consider the type of day.
#
# Second, average rental demand differs across weather conditions and seasons. This indicates that environmental and seasonal factors should also be considered when planning bike availability and operational resources.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Which hours have the highest average bike rental demand on working days versus weekends/holidays during 2011–2012, and what operational periods should be prioritized based on these differences?

# %%
# Visualize average rental demand by hour and day type

plt.figure(figsize=(14, 6))

sns.lineplot(
    data=hourly_demand,
    x='hr',
    y='cnt',
    hue='day_type',
    marker='o'
)

plt.title(
    'Average Bike Rental Demand by Hour and Day Type'
)

plt.xlabel('Hour of Day')
plt.ylabel('Average Number of Rentals')

plt.xticks(range(24))

plt.legend(
    title='Day Type'
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explanatory Analysis — Question 1
#
# The hourly analysis reveals distinct rental demand patterns between working days and weekends/holidays.
#
# On working days, the highest average rental demand occurs at **17:00**, with approximately **525.29 rentals**. Another substantial peak occurs at **08:00**, with approximately **477.01 rentals**.
#
# On weekends and holidays, the highest average rental demand occurs at **13:00**, with approximately **372.73 rentals**. Other high-demand periods are also concentrated during the afternoon.
#
# The peak demand on working days is approximately **40.92% higher** than the peak demand on weekends/holidays.
#
# These findings indicate that working-day demand is concentrated around commuting periods, while weekend and holiday demand is more concentrated during the afternoon.

# %% [markdown]
# ### Pertanyaan 2: How do weather conditions and seasons affect average bike rental demand during 2011–2012, and how should these patterns be considered in operational planning?

# %%
# Visualize average rental demand by weather condition

weather_plot = weather_summary.reset_index()

plt.figure(figsize=(11, 6))

sns.barplot(
    data=weather_plot,
    x='weather_name',
    y='average_rental'
)

plt.title(
    'Average Bike Rental Demand by Weather Condition'
)

plt.xlabel('Weather Condition')
plt.ylabel('Average Number of Rentals')

plt.xticks(rotation=20)

plt.tight_layout()
plt.show()

# %%
# Visualize average rental demand by season

season_plot = season_summary.reset_index()

plt.figure(figsize=(9, 6))

sns.barplot(
    data=season_plot,
    x='season_name',
    y='average_rental'
)

plt.title(
    'Average Bike Rental Demand by Season'
)

plt.xlabel('Season')
plt.ylabel('Average Number of Rentals')

plt.tight_layout()
plt.show()

# %%
# Visualize the combined relationship between season,
# weather condition, and rental demand

plt.figure(figsize=(12, 6))

sns.heatmap(
    weather_season,
    annot=True,
    fmt='.0f'
)

plt.title(
    'Average Bike Rental Demand by Season and Weather Condition'
)

plt.xlabel('Weather Condition')
plt.ylabel('Season')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explanatory Analysis — Question 2
#
# The analysis shows that weather conditions have a clear relationship with bike rental demand.
#
# Among the four weather categories, **Clear weather** has the highest average rental demand at approximately **204.87 rentals per hour**. This is followed by **Mist / Cloudy** conditions at approximately **175.17 rentals**, **Light Rain / Snow** at approximately **111.58 rentals**, and **Heavy Rain / Snow** at approximately **74.33 rentals**.
#
# Therefore, average rental demand decreases as weather conditions become less favorable. However, the Heavy Rain / Snow category contains only **3 observations**, so its average should be interpreted with caution because of the very small sample size.
#
# Seasonal differences are also evident. **Fall** has the highest average rental demand at approximately **236.02 rentals per hour**, followed by **Summer** at **208.34**, **Winter** at **198.87**, and **Spring** at **111.11 rentals per hour**.
#
# The combination of season and weather provides additional insight. For example, during **Fall**, average demand reaches approximately **244.49 rentals** under Clear weather and **224.85 rentals** under Mist / Cloudy conditions. In contrast, during **Spring**, average demand is substantially lower, with approximately **122.06 rentals** under Clear weather and only **58.65 rentals** under Light Rain / Snow.
#
# Overall, the results indicate that both **weather conditions and seasonal patterns should be considered when planning bike-sharing operations**. Favorable weather and high-demand seasons require greater preparation for bike availability, while unfavorable weather conditions may require lower operational capacity.

# %% [markdown]
# **Insight:**
#
# The visualizations clearly demonstrate that bike rental demand is not evenly distributed.
#
# The first visualization shows distinct hourly demand patterns between working days and weekends/holidays. The second set of visualizations shows that weather conditions and seasons are also associated with differences in rental demand.
#
# These patterns provide useful information for operational planning, particularly for allocating bike availability during periods of expected high demand.

# %% [markdown]
# ## Analisis Lanjutan
#
# ### Demand Level Segmentation
#
# As an additional analysis, bike rental observations are segmented into three demand levels:
#
# - Low Demand
# - Medium Demand
# - High Demand
#
# The segmentation uses quantile-based binning (`qcut`) rather than a machine-learning clustering algorithm.
#
# The purpose of this analysis is to identify the characteristics of periods with different levels of rental demand and provide a simple framework for operational monitoring.

# %%
# Divide rental observations into three demand levels

df_clean['demand_level'] = pd.qcut(
    df_clean['cnt'],
    q=3,
    labels=[
        'Low Demand',
        'Medium Demand',
        'High Demand'
    ]
)

df_clean[
    ['cnt', 'demand_level']
].head()
# Out:
#    cnt demand_level
# 0   16   Low Demand
# 1   40   Low Demand
# 2   32   Low Demand
# 3   13   Low Demand
# 4    1   Low Demand

# %%
# Summarize the characteristics of each demand level

demand_summary = (
    df_clean
    .groupby(
        'demand_level',
        observed=False
    )
    .agg(
        average_rental=('cnt', 'mean'),
        average_temperature=('temp', 'mean'),
        average_humidity=('hum', 'mean'),
        average_windspeed=('windspeed', 'mean'),
        observations=('cnt', 'count')
    )
)

demand_summary
# Out:
#                average_rental  average_temperature  average_humidity  \
# demand_level
# Low Demand          25.060376             0.408880          0.712465
# Medium Demand      144.305513             0.483507          0.617347
# High Demand        400.610002             0.599305          0.551422
#
#                average_windspeed  observations
# demand_level
# Low Demand              0.170820          5797
# Medium Demand           0.198687          5823
# High Demand             0.200818          5759

# %%
# Calculate the distribution of demand levels across hours

demand_by_hour = pd.crosstab(
    df_clean['hr'],
    df_clean['demand_level'],
    normalize='index'
) * 100

demand_by_hour
# Out:
# demand_level  Low Demand  Medium Demand  High Demand
# hr
# 0              75.344353      24.380165     0.275482
# 1              83.425414      16.574586     0.000000
# 2              91.608392       8.391608     0.000000
# 3              99.856528       0.143472     0.000000
# 4             100.000000       0.000000     0.000000
# 5             100.000000       0.000000     0.000000
# 6              47.586207      52.413793     0.000000
# 7              29.711142      21.870702    48.418157
# 8              11.416781      28.060523    60.522696
# 9               6.877579      48.968363    44.154058
# 10             13.892710      63.411279    22.696011
# 11             10.453920      54.332875    35.213205
# 12              7.417582      41.346154    51.236264
# 13              6.447188      44.307270    49.245542
# 14              7.681756      47.873800    44.444444
# 15              7.818930      41.975309    50.205761
# 16              3.698630      25.068493    71.232877
# ...

# %%
# Visualize demand-level distribution by hour

demand_by_hour.plot(
    kind='bar',
    stacked=True,
    figsize=(14, 7)
)

plt.title(
    'Distribution of Demand Levels by Hour'
)

plt.xlabel('Hour of Day')
plt.ylabel('Percentage (%)')

plt.legend(
    title='Demand Level'
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
#
# The demand-level segmentation provides a simple way to distinguish periods of low, medium, and high rental activity.
#
# The distribution across hours can help identify time periods that are more likely to experience high demand. This can complement the hourly analysis by providing an operational classification rather than focusing only on the average number of rentals.
#
# This segmentation can therefore be used as a simple monitoring framework for operational planning.

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - Conclusion for Question 1
#
# Bike rental demand varies substantially by hour and day type.
#
# During working days, the highest average rental demand occurs at **17:00**, with approximately **525.29 rentals**, while another high-demand period occurs at **08:00**, with approximately **477.01 rentals**.
#
# During weekends and holidays, the highest average rental demand occurs at **13:00**, with approximately **372.73 rentals**.
#
# The results indicate that working-day demand is concentrated around commuting periods, whereas weekend and holiday demand is concentrated mainly during the afternoon.
#
# ---
#
# - Conclusion for Question 2
#
# Weather conditions and seasons are associated with substantial differences in bike rental demand.
#
# Clear weather has the highest average rental demand at approximately **204.87 rentals per hour**, while Light Rain / Snow has a much lower average of approximately **111.58 rentals**. Heavy Rain / Snow has the lowest average at **74.33 rentals**, although this result is based on only three observations and should therefore be interpreted cautiously.
#
# Among the seasons, **Fall has the highest average rental demand at 236.02 rentals per hour**, while **Spring has the lowest at 111.11 rentals per hour**.
#
# The results suggest that bike-sharing demand is generally higher during favorable weather conditions and varies considerably across seasons. Therefore, weather and seasonal factors are important considerations for operational planning.

# %% [markdown]
# ### Recommendation Action Items
#
# 1. **Increase operational readiness during high-demand seasons.**
#
#    Fall has the highest average rental demand at approximately **236.02 rentals per hour**. The operator should ensure sufficient bike availability and operational capacity during this period.
#
# 2. **Prioritize availability during favorable weather conditions.**
#
#    Clear weather has the highest average rental demand. Operational teams should be prepared for increased demand when favorable weather is expected.
#
# 3. **Adjust operational capacity during periods of unfavorable weather.**
#
#    Rental demand is substantially lower during Light Rain / Snow conditions. The operator can consider adjusting bike redistribution and operational resources based on expected weather conditions.
#
# 4. **Pay particular attention to Spring.**
#
#    Spring has the lowest average rental demand at approximately **111.11 rentals per hour**. Historical demand during this season can be used to plan operational capacity more efficiently.
#
# 5. **Use weather and seasonal forecasts together.**
#
#    Operational planning should consider both season and weather conditions rather than relying on either factor independently. For example, Fall with Clear weather shows particularly high average demand at approximately **244.49 rentals per hour**.

# %%
## Export Clean Dataset
# Save the cleaned dataset for the dashboard

dashboard_data = df_clean.copy()

dashboard_data.to_csv(
    'main_data.csv',
    index=False
)

print("main_data.csv created successfully.")

files.download('main_data.csv')
# Out:
# main_data.csv created successfully.

# %%
# %%writefile dashboard.py

import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# ============================================================
# PAGE CONFIGURATION
# ============================================================

st.set_page_config(
    page_title="Bike Sharing Demand Dashboard",
    page_icon="🚲",
    layout="wide"
)


# ============================================================
# LOAD DATA
# ============================================================

@st.cache_data
def load_data():
    df = pd.read_csv("main_data.csv")

    # Convert date column
    df["dteday"] = pd.to_datetime(df["dteday"])

    return df


df = load_data()


# ============================================================
# TITLE
# ============================================================

st.title("🚲 Bike Sharing Demand Dashboard")

st.markdown(
    """
    This dashboard provides an interactive overview of bike-sharing
    demand based on hourly patterns, day type, weather conditions,
    and seasons during 2011–2012.
    """
)


# ============================================================
# SIDEBAR FILTERS
# ============================================================

st.sidebar.header("Dashboard Filters")


# Year filter
year_options = sorted(df["year"].dropna().unique())

selected_year = st.sidebar.multiselect(
    "Select Year",
    options=year_options,
    default=year_options
)


# Season filter
season_options = sorted(
    df["season_name"].dropna().unique()
)

selected_season = st.sidebar.multiselect(
    "Select Season",
    options=season_options,
    default=season_options
)


# Weather filter
weather_options = sorted(
    df["weather_name"].dropna().unique()
)

selected_weather = st.sidebar.multiselect(
    "Select Weather Condition",
    options=weather_options,
    default=weather_options
)


# Day type filter
day_type_options = sorted(
    df["day_type"].dropna().unique()
)

selected_day_type = st.sidebar.multiselect(
    "Select Day Type",
    options=day_type_options,
    default=day_type_options
)


# ============================================================
# APPLY FILTERS
# ============================================================

filtered_df = df[
    (df["year"].isin(selected_year)) &
    (df["season_name"].isin(selected_season)) &
    (df["weather_name"].isin(selected_weather)) &
    (df["day_type"].isin(selected_day_type))
].copy()


# Handle empty selections
if filtered_df.empty:

    st.warning(
        "No data is available for the selected filters. "
        "Please select at least one option from each filter."
    )

    st.stop()


# ============================================================
# KPI CALCULATIONS
# ============================================================

total_rentals = filtered_df["cnt"].sum()

average_rentals = filtered_df["cnt"].mean()

peak_hour = (
    filtered_df
    .groupby("hr")["cnt"]
    .mean()
    .idxmax()
)

peak_hour_demand = (
    filtered_df
    .groupby("hr")["cnt"]
    .mean()
    .max()
)


# ============================================================
# KPI DISPLAY
# ============================================================

st.subheader("Key Performance Indicators")

col1, col2, col3, col4 = st.columns(4)

with col1:
    st.metric(
        "Total Rentals",
        f"{total_rentals:,.0f}"
    )

with col2:
    st.metric(
        "Average Rentals / Hour",
        f"{average_rentals:,.2f}"
    )

with col3:
    st.metric(
        "Peak Hour",
        f"{int(peak_hour):02d}:00"
    )

with col4:
    st.metric(
        "Peak Average Demand",
        f"{peak_hour_demand:,.2f}"
    )


st.divider()


# ============================================================
# CHART 1 — HOURLY DEMAND
# ============================================================

st.subheader("1. Hourly Bike Rental Demand")

hourly_demand = (
    filtered_df
    .groupby(
        ["day_type", "hr"]
    )["cnt"]
    .mean()
    .reset_index()
)


fig1, ax1 = plt.subplots(
    figsize=(12, 5)
)

sns.lineplot(
    data=hourly_demand,
    x="hr",
    y="cnt",
    hue="day_type",
    marker="o",
    ax=ax1
)

ax1.set_title(
    "Average Bike Rental Demand by Hour and Day Type"
)

ax1.set_xlabel("Hour of Day")

ax1.set_ylabel(
    "Average Number of Rentals"
)

ax1.set_xticks(range(24))

ax1.legend(
    title="Day Type"
)

plt.tight_layout()

st.pyplot(fig1)

st.markdown(
    """
    **Business insight:** Working days tend to show stronger demand
    around commuting periods, while weekends and holidays tend to
    show higher demand during the afternoon.
    """
)


# ============================================================
# CHART 2 — WEATHER
# ============================================================

st.subheader("2. Bike Rental Demand by Weather Condition")

weather_summary = (
    filtered_df
    .groupby("weather_name")["cnt"]
    .mean()
    .sort_values(
        ascending=False
    )
    .reset_index()
)


fig2, ax2 = plt.subplots(
    figsize=(10, 5)
)

sns.barplot(
    data=weather_summary,
    x="weather_name",
    y="cnt",
    ax=ax2
)

ax2.set_title(
    "Average Bike Rental Demand by Weather Condition"
)

ax2.set_xlabel(
    "Weather Condition"
)

ax2.set_ylabel(
    "Average Number of Rentals"
)

ax2.tick_params(
    axis="x",
    rotation=20
)

plt.tight_layout()

st.pyplot(fig2)

st.markdown(
    """
    **Business insight:** Rental demand is generally higher under
    favorable weather conditions and decreases under less favorable
    weather conditions.
    """
)


# ============================================================
# CHART 3 — SEASON
# ============================================================

st.subheader("3. Bike Rental Demand by Season")

season_summary = (
    filtered_df
    .groupby("season_name")["cnt"]
    .mean()
    .sort_values(
        ascending=False
    )
    .reset_index()
)


fig3, ax3 = plt.subplots(
    figsize=(10, 5)
)

sns.barplot(
    data=season_summary,
    x="season_name",
    y="cnt",
    ax=ax3
)

ax3.set_title(
    "Average Bike Rental Demand by Season"
)

ax3.set_xlabel(
    "Season"
)

ax3.set_ylabel(
    "Average Number of Rentals"
)

plt.tight_layout()

st.pyplot(fig3)

st.markdown(
    """
    **Business insight:** Seasonal demand varies substantially.
    Historical seasonal patterns can therefore be used when planning
    bike availability and operational capacity.
    """
)


# ============================================================
# CHART 4 — DEMAND LEVEL
# ============================================================

st.subheader("4. Demand Level Distribution")

# Create demand categories using the filtered data

filtered_df["demand_level"] = pd.qcut(
    filtered_df["cnt"],
    q=3,
    labels=[
        "Low Demand",
        "Medium Demand",
        "High Demand"
    ],
    duplicates="drop"
)


demand_distribution = (
    filtered_df["demand_level"]
    .value_counts()
    .sort_index()
    .reset_index()
)

demand_distribution.columns = [
    "Demand Level",
    "Number of Observations"
]


fig4, ax4 = plt.subplots(
    figsize=(10, 5)
)

sns.barplot(
    data=demand_distribution,
    x="Demand Level",
    y="Number of Observations",
    ax=ax4
)

ax4.set_title(
    "Distribution of Bike Rental Demand Levels"
)

ax4.set_xlabel(
    "Demand Level"
)

ax4.set_ylabel(
    "Number of Observations"
)

plt.tight_layout()

st.pyplot(fig4)


# ============================================================
# OPERATIONAL RECOMMENDATIONS
# ============================================================

st.divider()

st.subheader("Operational Recommendations")

st.markdown(
    """
    Based on the analysis, the following operational actions are
    recommended:

    1. **Prioritize bike availability during peak working-day hours.**
       Additional operational capacity should be prepared around
       morning and afternoon commuting periods.

    2. **Increase operational readiness during high-demand seasons.**
       Historical seasonal demand should be considered when allocating
       bikes and operational resources.

    3. **Consider weather conditions in operational planning.**
       Favorable weather is associated with higher rental demand,
       while unfavorable weather tends to correspond with lower demand.

    4. **Use demand-level segmentation for operational monitoring.**
       Low, Medium, and High Demand categories can provide a simple
       framework for identifying periods requiring different levels
       of operational attention.
    """
)


# ============================================================
# DATA SUMMARY
# ============================================================

with st.expander("View Filtered Dataset"):

    st.dataframe(
        filtered_df,
        use_container_width=True
    )


st.caption(
    "Bike Sharing Dataset | Analysis period: 2011–2012"
)
# Out:
# Overwriting dashboard.py

# %%
# %%writefile requirements.txt
#
# streamlit
# pandas
# numpy
# matplotlib
# seaborn
# Out:
# Overwriting requirements.txt

# %%
# %%writefile README.md
# ````markdown
# # Bike Sharing Demand Analysis
#
# ## Project Overview
#
# This project analyzes the Bike Sharing Dataset to identify patterns and factors associated with bike rental demand.
#
# The analysis focuses on hourly rental patterns, differences between working days and weekends/holidays, weather conditions, and seasonal patterns.
#
# An interactive Streamlit dashboard is also provided to allow users to explore the analysis using different filters.
#
# ## Dataset
#
# The dataset used in this project is the **Bike Sharing Dataset**, which contains hourly bike rental information together with information about time, season, weather conditions, and other environmental variables.
#
# The dataset covers the period from **2011 to 2012**.
#
# ## Business Questions
#
# The analysis addresses the following business questions:
#
# 1. **When does bike rental demand reach its peak on working days compared with weekends and holidays?**
#
# 2. **How do weather conditions and seasons relate to bike rental demand?**
#
# These questions are intended to support operational planning, particularly bike availability and resource allocation.
#
# ## Data Analysis Process
#
# The analysis follows these main stages:
#
# 1. Data Gathering
# 2. Data Assessing
# 3. Data Cleaning
# 4. Exploratory Data Analysis (EDA)
# 5. Data Visualization
# 6. Explanatory Analysis
# 7. Conclusion and Recommendations
#
# ## Key Findings
#
# ### Hourly Demand
#
# Bike rental demand varies throughout the day and differs between working days and weekends/holidays.
#
# On working days, the highest average rental demand occurs around the commuting period, with the peak occurring at **17:00**.
#
# On weekends and holidays, demand is more concentrated during the afternoon, with the highest average occurring at approximately **13:00**.
#
# ### Weather Conditions
#
# Weather conditions are associated with differences in bike rental demand.
#
# Clear weather has the highest average rental demand at approximately **204.87 rentals per hour**, while Light Rain / Snow has a lower average of approximately **111.58 rentals per hour**.
#
# Heavy Rain / Snow has the lowest observed average at approximately **74.33 rentals per hour**. However, this category contains only three observations, so the result should be interpreted cautiously.
#
# ### Seasonal Patterns
#
# Rental demand also varies by season.
#
# Fall has the highest average rental demand at approximately **236.02 rentals per hour**, while Spring has the lowest average at approximately **111.11 rentals per hour**.
#
# ## Recommendations
#
# Based on the analysis, several operational actions are recommended:
#
# 1. Prioritize bike availability during peak working-day hours, particularly around commuting periods.
#
# 2. Increase operational readiness during high-demand seasons, especially Fall.
#
# 3. Consider weather conditions when planning bike redistribution and operational resources.
#
# 4. Use historical demand patterns to adjust operational capacity during periods of expected high or low demand.
#
# ## Streamlit Dashboard
#
# The project includes an interactive Streamlit dashboard.
#
# The dashboard provides:
#
# - Year filtering
# - Season filtering
# - Weather-condition filtering
# - Day-type filtering
# - Total rental KPI
# - Average rental KPI
# - Peak-hour KPI
# - Hourly demand visualization
# - Weather-demand visualization
# - Seasonal-demand visualization
# - Demand-level distribution
# - Filtered dataset preview
#
# ## Project Structure
#
# ```text
# submission/
# ├── dashboard/
# │   ├── dashboard.py
# │   └── main_data.csv
# │
# ├── data/
# │   └── hour.csv
# │
# ├── notebook.ipynb
# ├── README.md
# └── requirements.txt
# ````
#
# ## How to Run the Dashboard Locally
#
# ### 1. Install Python
#
# Make sure Python is installed on your computer.
#
# ### 2. Install the Required Libraries
#
# Open Terminal or Command Prompt and navigate to the project folder.
#
# Run:
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ### 3. Navigate to the Dashboard Folder
#
# Run:
#
# ```bash
# cd dashboard
# ```
#
# ### 4. Run Streamlit
#
# Run:
#
# ```bash
# streamlit run dashboard.py
# ```
#
# The dashboard will then be available through the local Streamlit address shown in the terminal, usually:
#
# ```text
# http://localhost:8501
# ```
#
# ## Author
#
# Bike Sharing Demand Analysis Project
#
# ```
# ```
# Out:
# Overwriting README.md
